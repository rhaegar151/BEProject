# %%
import tensorflow as tf
from tensorflow import keras

# %%
from singlestep import *

from math import sqrt
import pandas as pd
import numpy as np
import pickle
import os
from sklearn.metrics import mean_squared_error
from keras.layers import Dense,LSTM,Bidirectional,BatchNormalization,Dropout,Conv1D,GRU,MaxPooling1D
from keras.models import Sequential,Model
from keras.layers.merge import concatenate
from keras.callbacks import History, ModelCheckpoint
from keras import optimizers
from keras.engine.input_layer import Input
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler

# %%
def naya_split(data):  #CORRECT
    train,test=data[0:365*1*24+24*30*4],data[365*1*24+24*30*4:365*1*24+24*30*6]
    train=np.split(train,len(train)/24)
    test=np.split(test,len(test)/24)
    return np.array(train),np.array(test)

# %%
def nwo_split(data):  #CORRECT
    train,test=data[0:365*2],data[365*2:365*3-1]
    train=np.split(train,len(train)/5)
    test=np.split(test,len(test)/28)
    return np.array(train),np.array(test)

# %%
def main():
  data=pd.read_csv('C:\\Users\Gyanvir\Downloads\daily_delhi.csv',header=0,parse_dates=True,index_col=['No'])
  data=data.reindex(columns=["Ozone","year","month","day","hour","PM10","BP","SR","NH3","NOx","NO","NO2","PM2.5","SO2","CO"])
  #target variable ozone
  n_input=8
  min=data['Ozone'].min()
  max=data['Ozone'].max() 
  scaler = MinMaxScaler(feature_range=(0, 1))
  data = scaler.fit_transform(data)
    
  train,test=nwo_split(data)
  print(train.shape)
  print(test.shape)
  train_x,train_y=to_supervised(train,n_input,1)
  n_timesteps,n_features,n_outputs=train_x.shape[1],train_x.shape[2],train_y.shape[1]
  print(train_x.shape)
  print(train_y.shape)

  filename = 'C:\\Users\Gyanvir\Downloads\BEProject_Final\BEProject1\models\hourly_models\modeldelhiozone.sav'
  model = pickle.load(open(filename, 'rb'))
  #model=CNN_GRU(n_timesteps)  
  for i in range(31,35):                                
   model.get_layer(index=i).trainable=False                  #freezing 
  model.compile(optimizer='adam',loss='mse') 
  history = fit_model(train_x,train_y,model,0,0)             #finetuning 

  scores,final_score= model_eval(train,test,n_input,model,28,0)
  scores=[t*(max-min)+min for t in scores]
  print(scores)
  print('normalized')  
  print(final_score)  
  print(final_score*(max-min)+min)

# %%
if __name__=='__main__':
  main()
# Out:
# (146, 5, 15)
# (13, 28, 15)
# (722, 8, 15)
# (722, 1)
# Train on 649 samples, validate on 73 samples
# Epoch 1/5
# 649/649 [==============================] - 25s 38ms/step - loss: 0.0095 - val_loss: 0.0272
# Epoch 2/5
# 649/649 [==============================] - 9s 14ms/step - loss: 0.0089 - val_loss: 0.0280
# Epoch 3/5
# 649/649 [==============================] - 10s 15ms/step - loss: 0.0086 - val_loss: 0.0266
# Epoch 4/5
# 649/649 [==============================] - 9s 14ms/step - loss: 0.0086 - val_loss: 0.0273
# Epoch 5/5
# 649/649 [==============================] - 9s 13ms/step - loss: 0.0087 - val_loss: 0.0275
# model built
# (364, 1)
# [7.318240516645628, 11.211884815770397, 11.070339834166461, 15.927633761881335, 18.892715602626275, 15.967241172557083, 11.997926052246543, 7.936587985926206, 13.383808741076546, 15.142522536454495, 7.730427772600124, 15.933504668961703, 9.729013433424681, 7.926830484014273, 6.406752263767866, 10.161544893793, 11.473349646973348, 16.847602973791794, 9.163364585744596, 11.605256697251706, 7.994386728355489, 14.213830128502861, 10.215897613246746, 8.057080037809762, 14.77811520517186, 14.647764015939845, 8.624980290014369, 6.091700532532827]
# normalized
# 0.08545129426698414
# 11.970177379677065
